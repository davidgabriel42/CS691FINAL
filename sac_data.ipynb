# %%
import pandas as pd
import numpy as np
import pyarrow as pa
import re
import findspark
findspark.init('/home/dave/spark-2.4.1-bin-hadoop2.7/')
import pyspark
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark.sql import *
import sys
import os
from IPython.display import display, HTML
from pyspark.sql.functions import pandas_udf, PandasUDFType
import urllib
from bs4 import BeautifulSoup

url = "https://www.sierraavalanchecenter.org/archive?date_filter_op=%3C%3D&date_filter%5Bvalue%5D%5Bdate%5D=05%2F06%2F2019&date_filter%5Bmin%5D%5Bdate%5D=05%2F06%2F2019&date_filter%5Bmax%5D%5Bdate%5D=&items_per_page=200"

html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html,"lxml")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out
# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)
#[a-zA-Z]+\s+\d+,\s\d\d\d\d\sat\s\d:\d\d\s.*(CONSIDERABLE|HIGH)    
#CONSIDERABLE|HIGH|MODERATE|LOW

# %%
print(text)
# Out:
# Archived Avalanche Forecasts from the Sierra Avalanche Center | Sierra Avalanche Center
# Skip to main content
# Sierra Avalanche Center
# Backcountry Avalanche, Snow, and Weather Information for the greater Lake Tahoe area
# In partnership with:
# Responsive Links
# Forecasts
# Observations
# Donate
# Forecasts
# Forecast Links
# Today's Avalanche Forecast
# State of the Snowpack
# Forecast Archives
# Text Forecast
# Subscriptions
# Email
# RSS Feeds
# Forecast Tutorials
# The Danger Scale
# How to read the Forecast
# Avalanche Problems Explained
# Observations
# Observations
# Observations -List View
# Observations - Map View
# Week in Review
# Archived Observations - List View
# Archived Observations - Map View
# Incidents
# Incidents - List View
# Incidents - Map View
# Archived Incidents - List View
# Archived Incidents - Map View
# Submit Observations
# Submit Observations
# Subscriptions
# Email
# RSS Feeds
# Weather
# Remote Weather Stations
# Remote Weather Station Map
# ...

# %%
import re
for line in re.findall("([a-zA-Z]+\s+\d+,\s\d\d\d\d\sat\s\d+:\d\d)\s.*?(CONSIDERABLE|HIGH|MODERATE|LOW|EXTREME).*(CONSIDERABLE|HIGH|MODERATE|LOW|EXTREME)|([a-zA-Z]+\s+\d+,\s\d\d\d\d\sat\s\d+:\d\d)\s.*?(CONSIDERABLE|HIGH|MODERATE|LOW|EXTREME).*(CONSIDERABLE|HIGH|MODERATE|LOW|EXTREME)?", text):
    print(line)
# Out:
# ('April 21, 2019 at 6:30', 'LOW', 'MODERATE', '', '', '')
# ('', '', '', 'April 20, 2019 at 6:49', 'MODERATE', '')
# ('April 19, 2019 at 6:59', 'LOW', 'MODERATE', '', '', '')
# ('April 18, 2019 at 6:59', 'LOW', 'MODERATE', '', '', '')
# ('April 17, 2019 at 6:52', 'LOW', 'MODERATE', '', '', '')
# ('', '', '', 'April 16, 2019 at 6:55', 'MODERATE', '')
# ('April 15, 2019 at 6:45', 'LOW', 'MODERATE', '', '', '')
# ('April 14, 2019 at 6:49', 'LOW', 'MODERATE', '', '', '')
# ('April 13, 2019 at 6:59', 'LOW', 'MODERATE', '', '', '')
# ('April 12, 2019 at 6:59', 'LOW', 'MODERATE', '', '', '')
# ('', '', '', 'April 11, 2019 at 6:59', 'LOW', '')
# ('April 10, 2019 at 6:58', 'LOW', 'MODERATE', '', '', '')
# ('', '', '', 'April 9, 2019 at 6:55', 'MODERATE', '')
# ('', '', '', 'April 8, 2019 at 6:46', 'MODERATE', '')
# ('', '', '', 'April 7, 2019 at 6:45', 'MODERATE', '')
# ('', '', '', 'April 6, 2019 at 6:59', 'MODERATE', '')
# ('April 5, 2019 at 6:57', 'LOW', 'MODERATE', '', '', '')
# ...

# %%
# Out:
#   File "<ipython-input-3-b3b27da3ba8f>", line 1
#     pip install beautifulsoup4
#               ^
# SyntaxError: invalid syntax
